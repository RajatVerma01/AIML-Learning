# %% [markdown]
# ## Multiple Linear regression
#
# In Multiple Linear Regression, we try to find the best-fit relationship between one dependent variable (Y) and multiple independent variables (X₁, X₂, X₃, ...).
#
# Instead of using only one input feature like Simple Linear Regression, Multiple Linear Regression uses several features together to predict the output more accurately.
#
# The equation of Multiple Linear Regression is:
# y=m1*x1+m2*x2+......+b
#
# where m1,m2,m3...... are coefecient of features
# b is the intercept
# and x1,x2,x3....  are the input variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv('multiple.csv')

# %%
df.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
fig = px.scatter_3d(df, x='age', y='experience', z='income')
fig.show()

# %%
X=df.drop('income',axis=1)

# %%
X
# Out:
#     age  experience
# 0    25           1
# 1    30           3
# 2    47           2
# 3    32           5
# 4    43          10
# 5    51           7
# 6    28           5
# 7    33           4
# 8    37           5
# 9    39           8
# 10   29           1
# 11   47           9
# 12   54           5
# 13   51           4
# 14   44          12
# 15   41           6
# 16   58          17
# 17   23           1
# 18   44           9
# 19   37          10

# %%
y=df['income']
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#     age  experience
# 11   47           9
# 3    32           5
# 18   44           9
# 16   58          17
# 13   51           4
# 2    47           2
# 9    39           8
# 19   37          10
# 4    43          10
# 12   54           5
# 7    33           4
# 10   29           1
# 14   44          12
# 6    28           5

# %%
y_train
# Out:
# 11    46110
# 3     40130
# 18    44190
# 16    63600
# 13    34800
# 2     31580
# 9     45150
# 19    48700
# 4     47830
# 12    36720
# 7     37650
# 10    27840
# 14    51300
# 6     41340
# Name: income, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
m1,m2=lr.coef_

# %%
m1
# Out:
# np.float64(-98.34696501743636)

# %%
m2
# Out:
# np.float64(2168.245514090821)

# %% [markdown]
# Here we can see that two coefecients are generated because according to our data the equation of line will be y=m1x1+m2x2+b

# %%
b=lr.intercept_
b
# Out:
# np.float64(31112.751755503195)

# %%
# y=m1*x1+m2*x2+b
m1*25+m2*1+b
# Out:
# np.float64(30822.32314415811)

# %% [markdown]
# ## this is the predicted salary
